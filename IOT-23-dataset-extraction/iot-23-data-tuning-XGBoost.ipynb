# %% [markdown]
# # Supervised ML methods for anomaly detection in IOT to enahnce network security
# ## Part 4 - DATA TUNING - XGBOOST

# %% [markdown]
# The IoT-23 dataset is a collection of network traffic from Internet of Things (IoT) devices. It includes 20 malware captures executed in IoT devices, and 3 hotspot captures for benign IoT devices traffic12. The 3 hotspot captures are not being included in the data cleaning because this feature was not considered relevant for the specific analysis being performed.
#
# In this notebook, we load the processed dataset file and use it to tune one of the previously trained classification models.
#
# > **INPUT:** the cleaned and processed dataset csv file. <br>
# > **OUTPUT:** an analysis of the model's performance before/after tuning.

# %% [markdown]
# ***

# %%
# Import necessary libraries and modules
import pandas as pd
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import classification_report, precision_score, confusion_matrix, recall_score, accuracy_score, f1_score
from statistics import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
import xgboost as xgb
from joblib import dump
from sklearn.preprocessing import StandardScaler
from scipy import stats
import time
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import cross_val_score
from collections import Counter
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
# Set display options
pd.set_option('display.max_columns', None)
pd.set_option("display.float", "{:.2f}".format)

# %%
# Read the dataset
data_df = pd.read_csv('../CSV-data/processed/iot23_processed.csv', index_col=0)

# %%
# Split data into independent and dependent variables
data_X = data_df.drop("label", axis=1)
data_y = data_df["label"]
X_train, X_test, y_train, y_test = train_test_split(data_X, data_y, test_size=0.2, random_state=100)

# %%
# transform or normalize our data with standard scalar function
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
def print_score(clf, X_train, y_train, X_test, y_test, train=True):
    if train:
        pred = clf.predict(X_train)
        clf_report = pd.DataFrame(classification_report(y_train, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_train, pred)}\n")
        
    elif train==False:
        pred = clf.predict(X_test)
        clf_report = pd.DataFrame(classification_report(y_test, pred, output_dict=True))
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")

# %%
# Define the model
model = xgb.XGBClassifier()

# Define the oversampler and undersampler
oversampler = RandomOverSampler(sampling_strategy='minority')
undersampler = RandomUnderSampler(sampling_strategy='majority')

# Apply oversampling
X_over, y_over = oversampler.fit_resample(X_train, y_train)

# Apply undersampling
X_under, y_under = undersampler.fit_resample(X_train, y_train)

# Train and evaluate the model with oversampling
model.fit(X_over, y_over)
scores_over = cross_val_score(model, X_over, y_over, cv=5)

# Train and evaluate the model with undersampling
model.fit(X_under, y_under)
scores_under = cross_val_score(model, X_under, y_under, cv=5)

# Compare the performance
print(f'Average accuracy with oversampling: {scores_over.mean()}')
print(f'Average accuracy with undersampling: {scores_under.mean()}')
# Out:
# Average accuracy with oversampling: 0.9999714258337462
# Average accuracy with undersampling: 0.9998673907552412

# %%
# Count the number of instances in each class
counter = Counter(y_over)
counter = Counter(y_under)

# Print the number of instances in each class
# the number of instances in the minority class should be equal to the number of instances in the majority class.
for class_label, num_samples in counter.items():
    print(f'Class {class_label}: {num_samples} samples')
# Out:
# Class 0.0: 158360 samples
# Class 1.0: 158360 samples

# %%
data_X, data_y = make_classification(n_samples=158360, random_state=1000)
X_train, X_test, y_train, y_test = train_test_split(data_X, data_y, test_size=0.2, random_state=1000)

# %%
start = time.time()

# Define the model
model = xgb.XGBClassifier()

# Define the parameter grid
parameters = {"eta": [0.01, 0.1, 0.2, 0.3], # The learning rate
            "max_depth": [3, 5, 7, 10], # The maximum depth of each tree
            "min_child_weight": [1, 3, 5, 7], # Minimum number of samples required in a leaf node
            "subsample": [0.5, 0.7, 1.0], # Fraction of the training data used per iteration for row sampling
            "colsample_bytree": [0.5, 0.7, 1.0], # Fraction used per iteration for column sampling
}

# Initialize cross validation method
cross_validation_folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000)

# Initialize tuning process
grid = GridSearchCV(
    estimator=model,
    param_grid=parameters,
    scoring=['accuracy','recall','precision','f1'],
    cv=cross_validation_folds,
    verbose=100,
    refit='accuracy')

# Train the model
grid.fit(data_X, data_y)
best_params = grid.best_params_

print ("Best Parameters: {}".format(grid.best_params_))

end = time.time()
print('time cost: ',end - start, 'seconds')
# Out:
# Fitting 5 folds for each of 576 candidates, totalling 2880 fits
# [CV 1/5; 1/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.5
# [CV 1/5; 1/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.4s
# [CV 2/5; 1/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.5
# [CV 2/5; 1/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.5s
# [CV 3/5; 1/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.5
# [CV 3/5; 1/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 4/5; 1/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.5
# [CV 4/5; 1/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 5/5; 1/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.5
# [CV 5/5; 1/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 1/5; 2/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7
# [CV 1/5; 2/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.9s
# [CV 2/5; 2/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7
# [CV 2/5; 2/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.6s
# [CV 3/5; 2/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7
# [CV 3/5; 2/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 4/5; 2/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7
# [CV 4/5; 2/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 5/5; 2/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7
# [CV 5/5; 2/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.6s
# [CV 1/5; 3/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=1.0
# [CV 1/5; 3/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.7s
# [CV 2/5; 3/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=1.0
# [CV 2/5; 3/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.4s
# [CV 3/5; 3/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=1.0
# [CV 3/5; 3/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 4/5; 3/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=1.0
# [CV 4/5; 3/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 5/5; 3/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=1.0
# [CV 5/5; 3/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=1, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.4s
# [CV 1/5; 4/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.5
# [CV 1/5; 4/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.3s
# [CV 2/5; 4/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.5
# [CV 2/5; 4/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.4s
# [CV 3/5; 4/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.5
# [CV 3/5; 4/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.7s
# [CV 4/5; 4/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.5
# [CV 4/5; 4/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 5/5; 4/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.5
# [CV 5/5; 4/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 1/5; 5/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7
# [CV 1/5; 5/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.3s
# [CV 2/5; 5/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7
# [CV 2/5; 5/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.6s
# [CV 3/5; 5/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7
# [CV 3/5; 5/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.4s
# [CV 4/5; 5/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7
# [CV 4/5; 5/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.4s
# [CV 5/5; 5/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7
# [CV 5/5; 5/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 1/5; 6/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=1.0
# [CV 1/5; 6/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.3s
# [CV 2/5; 6/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=1.0
# [CV 2/5; 6/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.5s
# [CV 3/5; 6/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=1.0
# [CV 3/5; 6/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 4/5; 6/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=1.0
# [CV 4/5; 6/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 5/5; 6/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=1.0
# [CV 5/5; 6/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=3, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.5s
# [CV 1/5; 7/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.5
# [CV 1/5; 7/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.4s
# [CV 2/5; 7/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.5
# [CV 2/5; 7/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.3s
# [CV 3/5; 7/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.5
# [CV 3/5; 7/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 4/5; 7/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.5
# [CV 4/5; 7/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 5/5; 7/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.5
# [CV 5/5; 7/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 1/5; 8/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7
# [CV 1/5; 8/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.3s
# [CV 2/5; 8/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7
# [CV 2/5; 8/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.8s
# [CV 3/5; 8/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7
# [CV 3/5; 8/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.7s
# [CV 4/5; 8/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7
# [CV 4/5; 8/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 5/5; 8/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7
# [CV 5/5; 8/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 1/5; 9/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=1.0
# [CV 1/5; 9/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.3s
# [CV 2/5; 9/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=1.0
# [CV 2/5; 9/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.5s
# [CV 3/5; 9/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=1.0
# [CV 3/5; 9/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 4/5; 9/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=1.0
# [CV 4/5; 9/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 5/5; 9/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=1.0
# [CV 5/5; 9/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=5, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.4s
# [CV 1/5; 10/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.5
# [CV 1/5; 10/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.3s
# [CV 2/5; 10/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.5
# [CV 2/5; 10/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.3s
# [CV 3/5; 10/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.5
# [CV 3/5; 10/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 4/5; 10/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.5
# [CV 4/5; 10/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.5s
# [CV 5/5; 10/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.5
# [CV 5/5; 10/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 1/5; 11/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7
# [CV 1/5; 11/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.3s
# [CV 2/5; 11/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7
# [CV 2/5; 11/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.3s
# [CV 3/5; 11/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7
# [CV 3/5; 11/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.4s
# [CV 4/5; 11/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7
# [CV 4/5; 11/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 5/5; 11/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7
# [CV 5/5; 11/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 1/5; 12/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=1.0
# [CV 1/5; 12/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.5s
# [CV 2/5; 12/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=1.0
# [CV 2/5; 12/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.994) total time=   0.3s
# [CV 3/5; 12/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=1.0
# [CV 3/5; 12/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 4/5; 12/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=1.0
# [CV 4/5; 12/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 5/5; 12/576] START colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=1.0
# [CV 5/5; 12/576] END colsample_bytree=0.5, eta=0.01, max_depth=3, min_child_weight=7, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.3s
# [CV 1/5; 13/576] START colsample_bytree=0.5, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.5
# [CV 1/5; 13/576] END colsample_bytree=0.5, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   0.5s
# [CV 2/5; 13/576] START colsample_bytree=0.5, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.5
# [CV 2/5; 13/576] END colsample_bytree=0.5, eta=0.01, max_depth=5, min_child_weight=1, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.995) recall: (test=0.994) total time=   0
576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=3, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   1.0s
# [CV 1/5; 571/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.5
# [CV 1/5; 571/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   1.0s
# [CV 2/5; 571/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.5
# [CV 2/5; 571/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.995) recall: (test=0.994) total time=   0.8s
# [CV 3/5; 571/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.5
# [CV 3/5; 571/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.9s
# [CV 4/5; 571/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.5
# [CV 4/5; 571/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.9s
# [CV 5/5; 571/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.5
# [CV 5/5; 571/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.9s
# [CV 1/5; 572/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.7
# [CV 1/5; 572/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   1.2s
# [CV 2/5; 572/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.7
# [CV 2/5; 572/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.995) recall: (test=0.994) total time=   0.9s
# [CV 3/5; 572/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.7
# [CV 3/5; 572/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.8s
# [CV 4/5; 572/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.7
# [CV 4/5; 572/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   1.0s
# [CV 5/5; 572/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.7
# [CV 5/5; 572/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.8s
# [CV 1/5; 573/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=1.0
# [CV 1/5; 573/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   1.1s
# [CV 2/5; 573/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=1.0
# [CV 2/5; 573/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.995) recall: (test=0.994) total time=   0.9s
# [CV 3/5; 573/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=1.0
# [CV 3/5; 573/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.9s
# [CV 4/5; 573/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=1.0
# [CV 4/5; 573/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   1.0s
# [CV 5/5; 573/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=1.0
# [CV 5/5; 573/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=5, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   1.0s
# [CV 1/5; 574/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.5
# [CV 1/5; 574/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   1.1s
# [CV 2/5; 574/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.5
# [CV 2/5; 574/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.995) recall: (test=0.994) total time=   0.9s
# [CV 3/5; 574/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.5
# [CV 3/5; 574/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   1.0s
# [CV 4/5; 574/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.5
# [CV 4/5; 574/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.5; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.9s
# [CV 5/5; 574/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.5
# [CV 5/5; 574/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.5; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.8s
# [CV 1/5; 575/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.7
# [CV 1/5; 575/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   1.2s
# [CV 2/5; 575/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.7
# [CV 2/5; 575/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.994) total time=   0.8s
# [CV 3/5; 575/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.7
# [CV 3/5; 575/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.7; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.8s
# [CV 4/5; 575/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.7
# [CV 4/5; 575/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   1.0s
# [CV 5/5; 575/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.7
# [CV 5/5; 575/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=0.7; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.8s
# [CV 1/5; 576/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=1.0
# [CV 1/5; 576/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.995) recall: (test=0.995) total time=   1.0s
# [CV 2/5; 576/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=1.0
# [CV 2/5; 576/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.995) recall: (test=0.994) total time=   1.0s
# [CV 3/5; 576/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=1.0
# [CV 3/5; 576/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=1.0; accuracy: (test=0.994) f1: (test=0.994) precision: (test=0.994) recall: (test=0.995) total time=   0.9s
# [CV 4/5; 576/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=1.0
# [CV 4/5; 576/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.9s
# [CV 5/5; 576/576] START colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=1.0
# [CV 5/5; 576/576] END colsample_bytree=1.0, eta=0.3, max_depth=10, min_child_weight=7, subsample=1.0; accuracy: (test=0.995) f1: (test=0.995) precision: (test=0.994) recall: (test=0.995) total time=   0.8s
# Best Parameters: {'colsample_bytree': 0.5, 'eta': 0.2, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 0.7}
# time cost:  1812.89706325531 seconds

# %%
start1 = time.time()

xgb_clf = xgb.XGBClassifier(**best_params)

# Initialize the results for each classifier
accuracy_scores = []
recall_scores = []
precision_scores = []
f1_scores = []
best_f1 = -1
best_model = None

# Train the classifier
xgb_clf.fit(X_train, y_train)

# Predict the test samples
y_pred = xgb_clf.predict(X_test)

# Calculate and register accuracy metrics
accuracy_scores.append(accuracy_score(y_test, y_pred))
recall_scores.append(recall_score(y_test, y_pred))
precision_scores.append(precision_score(y_test, y_pred))
est_f1_score = f1_score(y_test, y_pred)
f1_scores.append(est_f1_score)

# Compare with best performing model
if best_f1 < est_f1_score:
    best_model = xgb_clf
    best_f1 = est_f1_score

print_score(xgb_clf, X_train, y_train, X_test, y_test, train=True)
print_score(xgb_clf, X_train, y_train, X_test, y_test, train=False)

end1 = time.time()
print('time cost: ',end1 - start1, 'seconds')
# Out:
# Train Result:
# ================================================
# Accuracy Score: 99.99%
# _______________________________________________
# CLASSIFICATION REPORT:
#                  0        1  accuracy  macro avg  weighted avg
# precision     1.00     1.00      1.00       1.00          1.00
# recall        1.00     1.00      1.00       1.00          1.00
# f1-score      1.00     1.00      1.00       1.00          1.00
# support   63442.00 63246.00      1.00  126688.00     126688.00
# _______________________________________________
# Confusion Matrix:
#  [[63436     6]
#  [    6 63240]]
#
# Test Result:
# ================================================
# Accuracy Score: 99.48%
# _______________________________________________
# CLASSIFICATION REPORT:
#                  0        1  accuracy  macro avg  weighted avg
# precision     0.99     1.00      0.99       0.99          0.99
# recall        1.00     0.99      0.99       0.99          0.99
# f1-score      0.99     0.99      0.99       0.99          0.99
# support   15768.00 15904.00      0.99   31672.00      31672.00
# _______________________________________________
# Confusion Matrix:
#  [[15690    78]
#  [   87 15817]]
#
# time cost:  1.3011975288391113 seconds

# %%
# Check and compare results and Store performance metrics
results = pd.DataFrame(index=["XGB Base", "XGB Tuned", "XGB Trained"], columns=["Accuracy", "Recall", "Precision", "F1","Time(in sec)"])
results.iloc[0] = [1.00, 1.00, 1.00, 1.00, 31.10] # Results obtained from previous phase
results.iloc[1] = [grid.cv_results_['mean_test_accuracy'][grid.best_index_],grid.cv_results_['mean_test_recall'][grid.best_index_], grid.cv_results_['mean_test_precision'][grid.best_index_], grid.cv_results_['mean_test_f1'][grid.best_index_],(end-start)]
results.iloc[2] = [mean(accuracy_scores),mean(recall_scores),mean(precision_scores),mean(f1_scores),(end1-start1)]
results
# Out:
#             Accuracy Recall Precision   F1 Time(in sec)
# XGB Base        1.00   1.00      1.00 1.00        31.10
# XGB Tuned       0.99   1.00      0.99 0.99      1812.90
# XGB Trained     0.99   0.99      1.00 0.99         1.30

# %%
# Predict probabilities
y_pred_proba = xgb_clf.predict_proba(X_test)[::,1]

# Compute False postive rate, and True positive rate
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

# Compute ROC AUC
roc_auc = metrics.roc_auc_score(y_test, y_pred_proba)

# Plot ROC curve
plt.plot(fpr,tpr,label="ROC curve, auc="+str(roc_auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ### RESULT ANALYSIS

# %% [markdown]
# - XGB Base: This is likely the model with default hyperparameters. It has perfect scores across all metrics with an accuracy of 1.00, recall of 1.00, precision of 1.00, F1 score of 1.00, and it took 31.10 seconds to run.
# - XGB Tuned: This model probably had its hyperparameters tuned for better performance. It shows slightly lower performance with an accuracy of 0.99, recall of 1.00, precision of 0.99, F1 score of 0.99, and it took significantly more time to run (1812.90 seconds).
# - XGB Trained: This model might have been further trained or fine-tuned on a specific dataset. It maintains high performance with an accuracy of 0.99, recall of 0.99, perfect precision of 1.00, F1 score of 0.99, and it’s the fastest with a runtime of 1.30 seconds.
# - These results indicate that while tuning and training the XGBoost model has led to improvements in efficiency, the base model already had perfect performance metrics.
# - The accuracy scores are quite high for both the training and testing sets.
# - Precision, Recall, and F1-score: All approximately 0.99 for both classes.
# - These results indicate that XGB model is performing well on both the training and testing sets with a high degree of precision, recall, and F1-score. Hence no overfitting or underfitting.
# - An AUC value of 0.9951 indicates a method is better and almost perfect ranking. A higher AUC means the model is better at distinguishing between the classes.
